# %%
from numpy import random
import numpy as np

x = random.multinomial(n=6, pvals=[1/6]*6, size=6)
print(x)
# Out:
# [[0 1 0 0 3 2]
#  [1 1 2 1 0 1]
#  [0 2 4 0 0 0]
#  [3 0 0 2 0 1]
#  [1 2 0 1 2 0]
#  [1 2 0 2 1 0]]

# %%
# plot
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='whitegrid')
plt.figure(figsize=(10, 6))
sns.barplot(x=np.arange(1, 7), y=x[0], palette='viridis')
plt.xlabel('Number on the dice')
plt.ylabel('Frequency')
plt.title('Multinomial Distribution')
plt.show()
