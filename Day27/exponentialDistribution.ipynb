# %%
from numpy import *

x = random.exponential(scale=2, size=(2,3))
print(x)
print(x.shape)
# Out:
# [[0.07092336 0.03648198 2.34882157]
#  [4.02481206 1.58409271 1.16570879]]
# (2, 3)

# %%
# visualization
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
sns.distplot(random.exponential(size=1000), hist=False, kde=True, color = 'blue', hist_kws={'edgecolor':'black'}, kde_kws={'linewidth': 2})
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2940\2889440666.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.exponential(size=1000), hist=False, kde=True, color = 'blue', hist_kws={'edgecolor':'black'}, kde_kws={'linewidth': 2})
