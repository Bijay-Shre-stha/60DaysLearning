# %%
from numpy import *

y = random.chisquare(df=2, size=(2,3))
print(y)
# Out:
# [[6.47910626 1.82990198 2.43857675]
#  [0.51250232 0.98707312 3.01588053]]

# %%
# Visualization

import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(y, hist=False, rug=True)
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_18284\789364261.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y, hist=False, rug=True)

# %%
from scipy.stats import chi2_contingency
import numpy as np
import seaborn as sns

data = np.array([[10, 10, 20], [20, 20, 20]])
chi2, p, dof, expected = chi2_contingency(data)
alpha = 0.05

print('p value is ' + str(p))
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (H0 holds true)')

# visualization
sns.distplot(data, hist=False, rug=True)
# Out:
# p value is 0.2493522087772962
# Independent (H0 holds true)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16056\2609361740.py:16: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data, hist=False, rug=True)
# <Axes: ylabel='Density'>
