# %%
import pandas as pd

data_frame = pd.read_csv('data.csv')
print(data_frame)
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories  (7, 'Duration')
# 0         60  2020/12/01    110       130     409.1               45
# 1         60  2020/12/02    117       145     479.0               45
# 2         60  2020/12/03    103       135     340.0               45
# 3         45  2020/12/04    109       175     282.4               45
# 4         45  2020/12/05    117       148     406.0               45
# 5         60  2020/12/06    102       127     300.0               45
# 6         60  2020/12/07    110       136     374.0               45
# 7        450  2020/12/08    104       134     253.3               45
# 8         30  2020/12/09    109       133     195.1               45
# 9         60  2020/12/10     98       124     269.0               45
# 10        60  2020/12/11    103       147     329.3               45
# 11        60  2020/12/12    100       120     250.7               45
# 12        60  2020/12/12    100       120     250.7               45
# ...

# %%
print(data_frame.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
data_frame.drop_duplicates(inplace=True)
print(data_frame)
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories  (7, 'Duration')
# 0         60  2020/12/01    110       130     409.1               45
# 1         60  2020/12/02    117       145     479.0               45
# 2         60  2020/12/03    103       135     340.0               45
# 3         45  2020/12/04    109       175     282.4               45
# 4         45  2020/12/05    117       148     406.0               45
# 5         60  2020/12/06    102       127     300.0               45
# 6         60  2020/12/07    110       136     374.0               45
# 7        450  2020/12/08    104       134     253.3               45
# 8         30  2020/12/09    109       133     195.1               45
# 9         60  2020/12/10     98       124     269.0               45
# 10        60  2020/12/11    103       147     329.3               45
# 11        60  2020/12/12    100       120     250.7               45
# 13        60  2020/12/13    106       128     345.3               45
# ...
